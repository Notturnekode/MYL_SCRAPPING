# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
import requests
import pandas as pd#

# %%
column_names = ['N°', 'Nombre', 'Imagen', 'Tipo', 'Fuerza', 'Coste de oro', 'Raza', 'Frecuencia', 'Edición', 'Habilidad', 'Código', 'Arte', 'Texto épico']

decksFirstEra = {'El_Reto', 'Mundo_G%C3%B3tico', 'La_Ira_del_Nahual', 'Ragnarok' , 'La_Cofrad%C3%ADa', 'Esp%C3%ADritu_de_Drag%C3%B3n'}

# %%
root = 'https://myl.fandom.com'
deckList = f'{root}/es/wiki/Categor%C3%ADa:Lista_de_Cartas'
page_html = requests.get(deckList)
page_soup = soup(page_html.text, "lxml")

# %%
box = page_soup.find('div' , class_='category-page__members')
deckList = box.findAll('a', class_= 'category-page__member-link', href=True)
#deckList

# %%
deckLinks = []
for link in deckList:
        deckLinks.append(link['href'])

# %%
decksLinkFE = []
for link in deckLinks:
    if any(i in link for i in decksFirstEra):
        decksLinkFE.append(link)

# %%
cardList = f'{root}{decksLinkFE[4]}'
print(cardList)
page_html = requests.get(cardList)
page_soup = soup(page_html.text, "lxml")
page_table = page_soup.find_all('table')[1] 

cardLinks= []
for row in page_table.find_all('tr'):
    cardRow = []
    for td in row.find_all('td'):
        td_check = td.find('a')
        if td_check is not None:
            link = td.a['href']
            cardRow.append(link)
        else:
            not_link = ''.join(td.stripped_strings)
            if not_link == '':
                 not_link = None
            cardRow.append(not_link)
    cardLinks.append(cardRow)


cardLinkList = []
for i in range(len(cardLinks)-1):
    cardLinkList.append(cardLinks[i+1][1])
    
print(cardLinkList)
print(cardList)
# Out:
# https://myl.fandom.com/es/wiki/Lista_de_cartas_de_La_Ira_del_Nahual
# ['/es/wiki/Anchancho', '/es/wiki/Yanomami', '/es/wiki/Auca', '/es/wiki/Toki', '/es/wiki/Flechero', '/es/wiki/Ira_del_Nahual', '/es/wiki/Ix_Chebel_Yax', '/es/wiki/Pachamama', '/es/wiki/Ix_Tabai', '/es/wiki/Sacrificio_Humano', '/es/wiki/K%27_Ak%27_Na', '/es/wiki/Machit%C3%BAn', '/es/wiki/Sotz%27_Na', '/es/wiki/Ix_Chel', '/es/wiki/Xochi_Yaoyotl', '/es/wiki/Ch%27_Ayin_Na', '/es/wiki/Cataratas_del_Iguaz%C3%BA', '/es/wiki/Revoluci%C3%B3n_de_los_Objetos', '/es/wiki/Rito_del_Dorado', '/es/wiki/Reducci%C3%B3n_de_Cabeza', '/es/wiki/M%C3%A1scara_del_Sol', '/es/wiki/Sacrificio_Gladiatorio', '/es/wiki/Iniciaci%C3%B3n_Guerrera', '/es/wiki/Camaxtle', '/es/wiki/Tonatiuh', '/es/wiki/Cacer%C3%ADa_del_Peyolt', '/es/wiki/Hu%C3%A1scar_y_Atahualpa', '/es/wiki/Macu%C3%B1', '/es/wiki/Ah_Puch', '/es/wiki/Xochiquetzal', '/es/wiki/T%C3%B3tem_de_Perro', '/es/wiki/T%C3%B3tem_del_C%C3%B3ndor', '/es/wiki/T%C3%B3tem_de_Conejo', '/es/wiki/T%C3%B3tem_del_%C3%81guila', '/es/wiki/T%C3%B3tem_de_Guanaco', '/es/wiki/T%C3%B3tem_de_Cocodrilo', '/es/wiki/T%C3%B3tem_del_Mono', '/es/wiki/T%C3%B3tem_de_Jaguar', '/es/wiki/T%C3%B3tem_del_Puma', '/es/wiki/T%C3%B3tem_de_Serpiente', '/es/wiki/Insignia_de_Toqui', '/es/wiki/Atlatl', '/es/wiki/Tepoztopilli', '/es/wiki/Boleadoras', '/es/wiki/Cerbatana', '/es/wiki/Honda', '/es/wiki/Macahuitl', '/es/wiki/Maza', '/es/wiki/Arco_y_Flechas', '/es/wiki/Tecpatl', '/es/wiki/Cueva_de_Quicav%C3%AD', '/es/wiki/Huitzil', '/es/wiki/Machi', '/es/wiki/Inca_Yupanqui', '/es/wiki/Tac%C3%A1n', '/es/wiki/Pahuahtun', '/es/wiki/Itzam_N%C3%A1', '/es/wiki/Nanahuatzin', '/es/wiki/Kenos', '/es/wiki/Cin_Teotl', '/es/wiki/Wiraqocha', '/es/wiki/Huehue_Teotl', '/es/wiki/Kalku', '/es/wiki/Runa_Urutrungu', '/es/wiki/Apu_Illa', '/es/wiki/Kukulcan', '/es/wiki/Inti', '/es/wiki/Tezcaltlipoca', '/es/wiki/Joon', '/es/wiki/Cipatonal_y_Oxmoco', '/es/wiki/Cunas', '/es/wiki/Tlaloques', '/es/wiki/Galvarino', '/es/wiki/Cangrejos', '/es/wiki/Tzitzimime', '/es/wiki/Hurac%C3%A1n', '/es/wiki/Rumi%C3%B1ahui', '/es/wiki/Caupolic%C3%A1n', '/es/wiki/Chacs', '/es/wiki/Guajiro', '/es/wiki/Cabrac%C3%A1n', '/es/wiki/Guerrero_%C3%81guila', '/es/wiki/Lautaro', '/es/wiki/Etsa', '/es/wiki/Karib', '/es/wiki/Cihuate_Teotl', '/es/wiki/%C3%91amand%C3%BA', '/es/wiki/Peri_Pill%C3%A1n', '/es/wiki/Umoara', '/es/wiki/Acihuatl', '/es/wiki/Tlaca_Tecolotl', '/es/wiki/Centzon_Totochtin', '/es/wiki/Ahu_Kin', '/es/wiki/Quetzalcoatl_Retorna', '/es/wiki/Chasqui', '/es/wiki/Tlazolteotl', '/es/wiki/Tsachila', '/es/wiki/Killa', '/es/wiki/Shuar', '/es/wiki/Moctezuma', '/es/wiki/Basilisco', '/es/wiki/Camahueto', '/es/wiki/Cuchivilu', '/es/wiki/Cuero', '/es/wiki/Caballo_Marino', '/es/wiki/Amaru', '/es/wiki/Chinivilu', '/es/wiki/Cuauht%C3%A9moc', '/es/wiki/Puchao', '/es/wiki/Tesoro_de_Guayac%C3%A1n', '/es/wiki/Trapelacucha', '/es/wiki/Collar_de_Man%C3%AD', '/es/wiki/Nariguera', '/es/wiki/Se%C3%B1or_de_Sip%C3%A1n', '/es/wiki/Uxmal', '/es/wiki/Machu_Picchu', '/es/wiki/Zampo%C3%B1a', '/es/wiki/Tzolkin', '/es/wiki/Cr%C3%A1neo_de_Cristal', '/es/wiki/Trutruca', '/es/wiki/Puerta_del_Sol_Tiahuanacu', '/es/wiki/Nazca', '/es/wiki/Columnas_de_Thulan', '/es/wiki/Tenochtitl%C3%A1n', '/es/wiki/El_Dorado', '/es/wiki/Ciudad_de_los_C%C3%A9sares']
# https://myl.fandom.com/es/wiki/Lista_de_cartas_de_La_Ira_del_Nahual

# %%
cardDetail =[]

title = ''
cardImage = ''
cardDescription = []
cardHability = ''
cardCode = ''
cardArtist = ''
cardHistory = ''

for i in range(len(cardLinkList)):
    #print(f'{root}{cardLinkList[i]}')
    cardList = f'{root}{cardLinkList[i]}'
    print(cardList)
    page_html = requests.get(cardList)
    page_soup = soup(page_html.text, "lxml")
    card_tables = page_soup.findAll('table', class_='table_black')

# Primera Tabla [0]... Header contiene nombre de Carta / Image contiene imagen / Description contiene: Tipo, Coste, Edición, Frecuencia
    table_header = card_tables[0].find('tr', class_='table_head_black')
    table_image = card_tables[0].find('tr', class_='table_body_black') 
    table_description = card_tables[0].findAll('tr', class_='') 

    title = table_header.find('b').getText()
    #cardDetail.append((i, title))
    cardImage = table_image.find('a', class_='image')

    #cardDetail.append((i, cardImage['href']))

    #for row in table_description:
     #   for th in row.find_all('th'):
      #      if th.text not in column_names:
       #         cardDescription.append(th.text.strip('\n'))
                 
    tr = card_tables[0].findAll('tr', class_='')

    typeFlag = 0
    costFlag = 0
    frecFlag = 0
    editionFlag = 0
    strengthFlag = 0
    razaFlag = 0

    typeCard = ''
    strengthCard = ''
    costCard = ''
    frecCard = ''
    editionCard = ''
    razaCard = ''

    for row in tr:
    #print(row)
        th = row.find('th')
        if th.getText().strip() == "Tipo":
            #print('Entre Tipo')
            typeCard = th.find_next('th').getText().strip('\n')
            typeFlag = 1
        elif th.getText().strip() == "Fuerza":
            #print('Entre Coste')
            strengthCard = th.find_next('th').getText().strip('\n')
            strengthFlag = 1
        elif th.getText().strip() == "Coste de oro":
            #print('Entre Coste')
            costCard = th.find_next('th').getText().strip('\n')
            costFlag = 1
        elif th.getText().strip() == "Raza":
            #print('Entre Coste')
            razaCard = th.find_next('th').getText().strip('\n')
            razaFlag = 1
        elif th.getText().strip() == "Frecuencia":
            #print('Entre Frecuencia')
            frecCard = th.find_next('th').getText().strip('\n')
            frecFlag = 1
        elif th.getText().strip() == "Edición":
            #print('Entre Edicion')
            editionCard = th.find_next('th').getText().strip('\n')
            editionFlag = 1
    
    # Con costo, Con Fuerza, Con Raza
    if costFlag != 0 and strengthFlag != 0 and razaFlag != 0:
     cardDescription.append(typeCard)
     cardDescription.append(strengthCard)
     cardDescription.append(costCard)
     cardDescription.append(razaCard)
     cardDescription.append(frecCard)
     cardDescription.append(editionCard)
    # Sin costo, Con Fuerza, Con Raza    
    elif costFlag == 0 and strengthFlag != 0 and razaFlag != 0:
     cardDescription.append(typeCard)
     cardDescription.append(strengthCard)
     cardDescription.append('Sin Costo')
     cardDescription.append(razaCard)
     cardDescription.append(frecCard)
     cardDescription.append(editionCard)
    # Con costo, Sin Fuerza, Con Raza
    elif costFlag != 0 and strengthFlag == 0 and razaFlag != 0:
     cardDescription.append(typeCard)
     cardDescription.append('Sin Fuerza')
     cardDescription.append(costCard)
     cardDescription.append(razaCard)
     cardDescription.append(frecCard)
     cardDescription.append(editionCard)
    # Con costo, Con Fuerza, Sin Raza
    elif costFlag != 0 and strengthFlag != 0 and razaFlag == 0:
     cardDescription.append(typeCard)
     cardDescription.append(strengthCard)
     cardDescription.append(costCard)
     cardDescription.append('Sin Raza')
     cardDescription.append(frecCard)
     cardDescription.append(editionCard) 
    # Sin costo, Sin Fuerza, Raza
    elif costFlag == 0 and strengthFlag == 0 and razaFlag != 0:
     cardDescription.append(typeCard)
     cardDescription.append('Sin Fuerza')
     cardDescription.append('Sin Costo')
     cardDescription.append(razaCard)
     cardDescription.append(frecCard)
     cardDescription.append(editionCard)   
     # Sin costo, Con Fuerza, Sin Raza
    elif costFlag == 0 and strengthFlag != 0 and razaFlag == 0:
     cardDescription.append(typeCard)
     cardDescription.append(strengthCard)
     cardDescription.append('Sin Costo')
     cardDescription.append('Sin Raza')
     cardDescription.append(frecCard)
     cardDescription.append(editionCard)
    # Con costo, Sin Fuerza, Sin Raza
    elif costFlag != 0 and strengthFlag == 0 and razaFlag == 0:
     cardDescription.append(typeCard)
     cardDescription.append('Sin Fuerza')
     cardDescription.append(costCard)
     cardDescription.append('Sin Raza')
     cardDescription.append(frecCard)
     cardDescription.append(editionCard)  
    # Sin costo, Sin Fuerza, Sin Raza    
    elif costFlag == 0 and strengthFlag == 0 and razaFlag == 0:
     cardDescription.append(typeCard)
     cardDescription.append('Sin Fuerza')
     cardDescription.append('Sin Costo')
     cardDescription.append('Sin Raza')
     cardDescription.append(frecCard)
     cardDescription.append(editionCard)
 
    #print(card_description)

# Impresión Segunda y tercera Tabla [1]...
#Para Cartas con Habilidad: Header contiene Label Habilidad / Body descripción de la habilidad.
#Para Cartas sin Habilidad: Contiene el Código y Arte  


#Valido si la carta tiene Habilidad#

    card_with_hability = card_tables[1].find('td')
    #card_with_No_hability = card_tables[1].find('td')

    if (card_with_hability.getText().strip('\n') == "Habilidad"):
        #print('Si tengo')
        hability_flag = 1
        tr = card_tables[1].find('tr')
        td = tr.find('td')
        #cardDetail.append((i, td.find_next('td').text.strip()))
        cardHability = td.find_next('td').text.strip()
    
        more_details = card_tables[2].find('tr', class_='table_body_black')
    #print(more_details)
        for td in more_details.find('td'):
            cardCode = td.text.strip()
            cardArtist = td.find_next('td').text.strip()
            #cardDetail.append((i,td.text.strip()))
            #cardDetail.append((i,td.find_next('td').text.strip()))
        card_history = card_tables[3].find('tr', class_='table_body_black')
    #print(more_details)
        for td in card_history.find('td'):
            cardHistory = td.text.strip()
            #cardDetail.append((i,td.text.strip()))
            #cardDetail.append(td.find_next('td').text.strip())
        
        #cardDetail.append((i, title, cardImage['href']))
        
#Carta sin Habilidad#            
    else: 
    #print('No tengo')
        #cardDetail.append('Sin Habilidad')
        cardHability = 'Sin Habilidad'
        more_details = card_tables[1].find('tr', class_='table_body_black')
    #print(more_details)
        for td in more_details.find('td'):
            cardCode = td.text.strip()
            cardArtist = td.find_next('td').text.strip()
            #cardDetail.append((i,td.text.strip()))
            #cardDetail.append((i,td.find_next('td').text.strip()))
        card_history = card_tables[2].find('tr', class_='table_body_black')
    #print(more_details)
        for td in card_history.find('td'):
            cardHistory = td.text.strip()
            #cardDetail.append((i,td.text.strip()))
        
    cardDetail.append((i, title, cardImage['href'], cardDescription[0], cardDescription[1], cardDescription[2], cardDescription[3], cardDescription[4], cardDescription[5], cardHability, cardCode, cardArtist, cardHistory))
    cardDescription = []
        
print('Estoy al final')
print(cardDetail)
# Out:
# https://myl.fandom.com/es/wiki/Anchancho
# https://myl.fandom.com/es/wiki/Yanomami
# https://myl.fandom.com/es/wiki/Auca
# https://myl.fandom.com/es/wiki/Toki
# https://myl.fandom.com/es/wiki/Flechero
# https://myl.fandom.com/es/wiki/Ira_del_Nahual
# https://myl.fandom.com/es/wiki/Ix_Chebel_Yax
# https://myl.fandom.com/es/wiki/Pachamama
# https://myl.fandom.com/es/wiki/Ix_Tabai
# https://myl.fandom.com/es/wiki/Sacrificio_Humano
# https://myl.fandom.com/es/wiki/K%27_Ak%27_Na
# https://myl.fandom.com/es/wiki/Machit%C3%BAn
# https://myl.fandom.com/es/wiki/Sotz%27_Na
# https://myl.fandom.com/es/wiki/Ix_Chel
# https://myl.fandom.com/es/wiki/Xochi_Yaoyotl
# https://myl.fandom.com/es/wiki/Ch%27_Ayin_Na
# https://myl.fandom.com/es/wiki/Cataratas_del_Iguaz%C3%BA
# https://myl.fandom.com/es/wiki/Revoluci%C3%B3n_de_los_Objetos
# https://myl.fandom.com/es/wiki/Rito_del_Dorado
# https://myl.fandom.com/es/wiki/Reducci%C3%B3n_de_Cabeza
# https://myl.fandom.com/es/wiki/M%C3%A1scara_del_Sol
# https://myl.fandom.com/es/wiki/Sacrificio_Gladiatorio
# https://myl.fandom.com/es/wiki/Iniciaci%C3%B3n_Guerrera
# https://myl.fandom.com/es/wiki/Camaxtle
# https://myl.fandom.com/es/wiki/Tonatiuh
# https://myl.fandom.com/es/wiki/Cacer%C3%ADa_del_Peyolt
# https://myl.fandom.com/es/wiki/Hu%C3%A1scar_y_Atahualpa
# https://myl.fandom.com/es/wiki/Macu%C3%B1
# https://myl.fandom.com/es/wiki/Ah_Puch
# https://myl.fandom.com/es/wiki/Xochiquetzal
# https://myl.fandom.com/es/wiki/T%C3%B3tem_de_Perro
# https://myl.fandom.com/es/wiki/T%C3%B3tem_del_C%C3%B3ndor
# https://myl.fandom.com/es/wiki/T%C3%B3tem_de_Conejo
# https://myl.fandom.com/es/wiki/T%C3%B3tem_del_%C3%81guila
# https://myl.fandom.com/es/wiki/T%C3%B3tem_de_Guanaco
# https://myl.fandom.com/es/wiki/T%C3%B3tem_de_Cocodrilo
# https://myl.fandom.com/es/wiki/T%C3%B3tem_del_Mono
# https://myl.fandom.com/es/wiki/T%C3%B3tem_de_Jaguar
# https://myl.fandom.com/es/wiki/T%C3%B3tem_del_Puma
# https://myl.fandom.com/es/wiki/T%C3%B3tem_de_Serpiente
# https://myl.fandom.com/es/wiki/Insignia_de_Toqui
# https://myl.fandom.com/es/wiki/Atlatl
# https://myl.fandom.com/es/wiki/Tepoztopilli
# https://myl.fandom.com/es/wiki/Boleadoras
# https://myl.fandom.com/es/wiki/Cerbatana
# https://myl.fandom.com/es/wiki/Honda
# https://myl.fandom.com/es/wiki/Macahuitl
# https://myl.fandom.com/es/wiki/Maza
# https://myl.fandom.com/es/wiki/Arco_y_Flechas
# https://myl.fandom.com/es/wiki/Tecpatl
# https://myl.fandom.com/es/wiki/Cueva_de_Quicav%C3%AD
# https://myl.fandom.com/es/wiki/Huitzil
# https://myl.fandom.com/es/wiki/Machi
# https://myl.fandom.com/es/wiki/Inca_Yupanqui
# https://myl.fandom.com/es/wiki/Tac%C3%A1n
# https://myl.fandom.com/es/wiki/Pahuahtun
# https://myl.fandom.com/es/wiki/Itzam_N%C3%A1
# https://myl.fandom.com/es/wiki/Nanahuatzin
# https://myl.fandom.com/es/wiki/Kenos
# https://myl.fandom.com/es/wiki/Cin_Teotl
# https://myl.fandom.com/es/wiki/Wiraqocha
# https://myl.fandom.com/es/wiki/Huehue_Teotl
# https://myl.fandom.com/es/wiki/Kalku
# https://myl.fandom.com/es/wiki/Runa_Urutrungu
# https://myl.fandom.com/es/wiki/Apu_Illa
# https://myl.fandom.com/es/wiki/Kukulcan
# https://myl.fandom.com/es/wiki/Inti
# https://myl.fandom.com/es/wiki/Tezcaltlipoca
# https://myl.fandom.com/es/wiki/Joon
# https://myl.fandom.com/es/wiki/Cipatonal_y_Oxmoco
# https://myl.fandom.com/es/wiki/Cunas
# https://myl.fandom.com/es/wiki/Tlaloques
# https://myl.fandom.com/es/wiki/Galvarino
# https://myl.fandom.com/es/wiki/Cangrejos
# https://myl.fandom.com/es/wiki/Tzitzimime
# https://myl.fandom.com/es/wiki/Hurac%C3%A1n
# https://myl.fandom.com/es/wiki/Rumi%C3%B1ahui
# https://myl.fandom.com/es/wiki/Caupolic%C3%A1n
# https://myl.fandom.com/es/wiki/Chacs
# https://myl.fandom.com/es/wiki/Guajiro
# https://myl.fandom.com/es/wiki/Cabrac%C3%A1n
# https://myl.fandom.com/es/wiki/Guerrero_%C3%81guila
# https://myl.fandom.com/es/wiki/Lautaro
# https://myl.fandom.com/es/wiki/Etsa
# https://myl.fandom.com/es/wiki/Karib
# https://myl.fandom.com/es/wiki/Cihuate_Teotl
# https://myl.fandom.com/es/wiki/%C3%91amand%C3%BA
# https://myl.fandom.com/es/wiki/Peri_Pill%C3%A1n
# https://myl.fandom.com/es/wiki/Umoara
# https://myl.fandom.com/es/wiki/Acihuatl
# https://myl.fandom.com/es/wiki/Tlaca_Tecolotl
# https://myl.fandom.com/es/wiki/Centzon_Totochtin
# https://myl.fandom.com/es/wiki/Ahu_Kin
# https://myl.fandom.com/es/wiki/Quetzalcoatl_Retorna
# https://myl.fandom.com/es/wiki/Chasqui
# https://myl.fandom.com/es/wiki/Tlazolteotl
# https://myl.fandom.com/es/wiki/Tsachila
# https://myl.fandom.com/es/wiki/Killa
# https://myl.fandom.com/es/wiki/Shuar
# https://myl.fandom.com/es/wiki/Moctezuma
# https://myl.fandom.com/es/wiki/Basilisco
# https://myl.fandom.com/es/wiki/Camahueto
# https://myl.fandom.com/es/wiki/Cuchivilu
# https://myl.fandom.com/es/wiki/Cuero
# https://myl.fandom.com/es/wiki/Caballo_Marino
# https://myl.fandom.com/es/wiki/Amaru
# https://myl.fandom.com/es/wiki/Chinivilu
# https://myl.fandom.com/es/wiki/Cuauht%C3%A9moc
# https://myl.fandom.com/es/wiki/Puchao
# https://myl.fandom.com/es/wiki/Tesoro_de_Guayac%C3%A1n
# https://myl.fandom.com/es/wiki/Trapelacucha
# https://myl.fandom.com/es/wiki/Collar_de_Man%C3%AD
# https://myl.fandom.com/es/wiki/Nariguera
# https://myl.fandom.com/es/wiki/Se%C3%B1or_de_Sip%C3%A1n
# https://myl.fandom.com/es/wiki/Uxmal
# https://myl.fandom.com/es/wiki/Machu_Picchu
# https://myl.fandom.com/es/wiki/Zampo%C3%B1a
# https://myl.fandom.com/es/wiki/Tzolkin
# https://myl.fandom.com/es/wiki/Cr%C3%A1neo_de_Cristal
# https://myl.fandom.com/es/wiki/Trutruca
# https://myl.fandom.com/es/wiki/Puerta_del_Sol_Tiahuanacu
# https://myl.fandom.com/es/wiki/Nazca
# https://myl.fandom.com/es/wiki/Columnas_de_Thulan
# https://myl.fandom.com/es/wiki/Tenochtitl%C3%A1n
# https://myl.fandom.com/es/wiki/El_Dorado
# https://myl.fandom.com/es/wiki/Ciudad_de_los_C%C3%A9sares
# Estoy al final
# [(0, 'Anchancho', 'https://static.wikia.nocookie.net/myl-tcg/images/9/9f/Anchancho_2.png/revision/latest?cb=20211020010617&path-prefix=es', 'Talismán', 'Sin Fuerza', '4', 'Sin Raza', 'Cortesano', 'La Ira del Nahual', 'Eliges al Aliado de mayor fuerza de tu oponente y lo pones en su cementerio.', '1 - 126 / Primera Edición', 'Gabriel Rodríguez', 'Con su mano de lana te engatusa suavemente y su mano de hierro te ahoga cruelmente... Devorará la piedra de tu frente y morirás prontamente.'), (1, 'Yanomami', 'https://static.wikia.nocookie.net/myl-tcg/images/c/c1/Yanomami_2.png/revision/latest?cb=20211020011746&path-prefix=es', 'Talismán', 'Sin Fuerza', '4', 'Sin Raza', 'Cortesano', 'La Ira del Nahual', 'Destruye un Aliado oponente a tu elección.', '2 - 126 / Primera Edición', 'Juan Vásquez/Rodrigo Elgueta', 'Canciones de pájaros multicolores llenan la selva. La vida libre es buena para quien se hace cargo de sí mismo y de los suyos.'), (2, 'Auca', 'https://static.wikia.nocookie.net/myl-tcg/images/f/ff/Auca_2.png/revision/latest?cb=20211020012242&path-prefix=es', 'Talismán', 'Sin Fuerza', '1', 'Sin Raza', 'Cortesano', 'La Ira del Nahual', 'En el momento que tu oponente juegue un Arma desde su mano, puedes jugar esta carta y mandar a su cementerio dicha Arma.', '3 - 126 / Primera Edición', 'Juan Vásquez/Rodrigo Elgueta', 'Ser rebelde, que ningún imperio te aplaste. Ser libre, gobernar la propia vida y alzar la cabeza con dignidad en el corazón.'), (3, 'Toki', 'https://static.wikia.nocookie.net/myl-tcg/images/7/74/Toki_2.png/revision/latest?cb=20211020013302&path-prefix=es', 'Talismán', 'Sin Fuerza', '1', 'Sin Raza', 'Cortesano', 'La Ira del Nahual', 'En el momento que tu oponente juegue un Tótem desde su mano, puedes jugar esta carta y mandar a su cementerio dicho Tótem.', '4 - 126 / Primera Edición', 'Waldo Retamales', 'La guerra se acerca; sólo el más fuerte, el más veloz, el más valiente, el más astuto, es el líder..., sólo el que demuestra ser eficaz y ningún otro.'), (4, 'Flechero', 'https://static.wikia.nocookie.net/myl-tcg/images/6/64/Flechero.png/revision/latest?cb=20221213082716&path-prefix=es', 'Talismán', 'Sin Fuerza', '1', 'Sin Raza', 'Cortesano', 'La Ira del Nahual', 'En el momento que tu oponente juegue un Talismán desde su mano, puedes jugar esta carta y mandar a su cementerio dicho Talismán.', '5 - 126 / Primera Edición', 'Mauricio Herrera', 'Distinguido en su carrera como brujo, el verdugo implacable ejecuta la pena de muerte sentenciada por la mayoría.'), (5, 'Ira del Nahual', 'https://static.wikia.nocookie.net/myl-tcg/images/4/47/Ira_del_Nahual.jpg/revision/latest?cb=20201204144856&path-prefix=es', 'Talismán', 'Sin Fuerza', '4', 'Sin Raza', 'Real', 'La Ira del Nahual', 'Todos tus aliados que ataquen son imbloqueables por este turno.', '6 - 126 / Primera Edición', 'Mauricio Herrera', 'El mago convertido en su otro yo, en su doble, actúa en éste y otros mundos. Así la justicia abate al intrigante, al traidor, al usurpador.'), (6, 'Ix Chebel Yax', 'https://static.wikia.nocookie.net/myl-tcg/images/4/48/Ix_Chebel_Yax.jpg/revision/latest?cb=20201204145633&path-prefix=es', 'Talismán', 'Sin Fuerza', '2', 'Sin Raza', 'Cortesano', 'La Ira del Nahual', 'Puedes buscar un talismán en tu castillo y ponerlo en tu mano.', '7 - 126 / Primera Edición', 'Andrés Blanco', 'Abuela dueña de la tierra, hacedora de lluvia, pinta de rojo con un pincel: la tierra, las hojas, la corteza del árbol y la cresta del pájaro carpintero.'), (7, 'Pachamama', 'https://static.wikia.nocookie.net/myl-tcg/images/b/b5/Pachamama.jpg/revision/latest?cb=20201204152156&path-prefix=es', 'Talismán', 'Sin Fuerza', '2', 'Sin Raza', 'Real', 'La Ira del Nahual', 'Puedes buscar un aliado en tu castillo y ponerlo en tu mano.', '8 - 126 / Primera Edición', 'Dreg', 'Madre nuestra, eres tiempo que cura los dolores, tiempo que distribuye las estaciones, tierra fecunda. Todos venimos de ti y aceptamos tu ley.'), (8, 'Ix Tabai', 'https://static.wikia.nocookie.net/myl-tcg/ima ...

# %%
df = pd.DataFrame(cardDetail)
df.columns = column_names
df.head(13)


#cardTable = card_page_soup.find('table', class_='lista sortable mergetable col2cen col3cen col4cen center')
#cardList = cardTable.findAll('tr', class_= '')
#print(cardList[0])
# Out:
#     N°             Nombre                                             Imagen  \
# 0    0          Anchancho  https://static.wikia.nocookie.net/myl-tcg/imag...
# 1    1           Yanomami  https://static.wikia.nocookie.net/myl-tcg/imag...
# 2    2               Auca  https://static.wikia.nocookie.net/myl-tcg/imag...
# 3    3               Toki  https://static.wikia.nocookie.net/myl-tcg/imag...
# 4    4           Flechero  https://static.wikia.nocookie.net/myl-tcg/imag...
# 5    5     Ira del Nahual  https://static.wikia.nocookie.net/myl-tcg/imag...
# 6    6      Ix Chebel Yax  https://static.wikia.nocookie.net/myl-tcg/imag...
# 7    7          Pachamama  https://static.wikia.nocookie.net/myl-tcg/imag...
# 8    8           Ix Tabai  https://static.wikia.nocookie.net/myl-tcg/imag...
# 9    9  Sacrificio Humano  https://static.wikia.nocookie.net/myl-tcg/imag...
# 10  10          K' Ak' Na  https://static.wikia.nocookie.net/myl-tcg/imag...
# 11  11           Machitún  https://static.wikia.nocookie.net/myl-tcg/imag...
# 12  12           Sotz' Na  https://static.wikia.nocookie.net/myl-tcg/imag...
#
#         Tipo      Fuerza Coste de oro      Raza Frecuencia            Edición  \
# 0   Talismán  Sin Fuerza            4  Sin Raza  Cortesano  La Ira del Nahual
# 1   Talismán  Sin Fuerza            4  Sin Raza  Cortesano  La Ira del Nahual
# 2   Talismán  Sin Fuerza            1  Sin Raza  Cortesano  La Ira del Nahual
# 3   Talismán  Sin Fuerza            1  Sin Raza  Cortesano  La Ira del Nahual
# 4   Talismán  Sin Fuerza            1  Sin Raza  Cortesano  La Ira del Nahual
# 5   Talismán  Sin Fuerza            4  Sin Raza       Real  La Ira del Nahual
# 6   Talismán  Sin Fuerza            2  Sin Raza  Cortesano  La Ira del Nahual
# 7   Talismán  Sin Fuerza            2  Sin Raza       Real  La Ira del Nahual
# 8   Talismán  Sin Fuerza            2  Sin Raza    Vasallo  La Ira del Nahual
# 9   Talismán  Sin Fuerza            5  Sin Raza       Real  La Ira del Nahual
# 10  Talismán  Sin Fuerza            4  Sin Raza       Real  La Ira del Nahual
# 11  Talismán  Sin Fuerza            2  Sin Raza       Real  La Ira del Nahual
# 12  Talismán  Sin Fuerza            3  Sin Raza       Real  La Ira del Nahual
#
#                                             Habilidad  \
# 0   Eliges al Aliado de mayor fuerza de tu oponent...
# 1          Destruye un Aliado oponente a tu elección.
# 2   En el momento que tu oponente juegue un Arma d...
# 3   En el momento que tu oponente juegue un Tótem ...
# 4   En el momento que tu oponente juegue un Talism...
# 5   Todos tus aliados que ataquen son imbloqueable...
# 6   Puedes buscar un talismán en tu castillo y pon...
# 7   Puedes buscar un aliado en tu castillo y poner...
# 8   Si en el turno anterior fuiste atacado, tu opo...
# 9   Por cada aliado en juego, tu oponente debe pag...
# 10  El oponente descarta 2 cartas de su mano al ce...
# 11  Reduce a cero todo el daño hecho por tu oponen...
# 12  En el momento que tu oponente juegue un aliado...
#
#                         Código                          Arte  \
# 0    1 - 126 / Primera Edición             Gabriel Rodríguez
# 1    2 - 126 / Primera Edición  Juan Vásquez/Rodrigo Elgueta
# 2    3 - 126 / Primera Edición  Juan Vásquez/Rodrigo Elgueta
# 3    4 - 126 / Primera Edición               Waldo Retamales
# 4    5 - 126 / Primera Edición              Mauricio Herrera
# 5    6 - 126 / Primera Edición              Mauricio Herrera
# 6    7 - 126 / Primera Edición                 Andrés Blanco
# 7    8 - 126 / Primera Edición                          Dreg
# 8    9 - 126 / Primera Edición                          Dreg
# 9   10 - 126 / Primera Edición                          Dreg
# 10  11 - 126 / Primera Edición                 Alan Robinson
# 11  12 - 126 / Primera Edición              Mauricio Herrera
# 12  13 - 126 / Primera Edición             Gabriel Rodríguez
#
#                                           Texto épico
# 0   Con su mano de lana te engatusa suavemente y s...
# 1   Canciones de pájaros multicolores llenan la se...
# 2   Ser rebelde, que ningún imperio te aplaste. Se...
# 3   La guerra se acerca; sólo el más fuerte, el má...
# 4   Distinguido en su carrera como brujo, el verdu...
# 5   El mago convertido en su otro yo, en su doble,...
# 6   Abuela dueña de la tierra, hacedora de lluvia,...
# 7   Madre nuestra, eres tiempo que cura los dolore...
# 8   Por el llanto de la señora de la cuerda. Por p...
# 9   En la piedra Techcatl la ofrenda llega al luga...
# 10  En la sexta casa de tormento en Xibalba, me ag...
# 11  En la purificación, la machi en trance, dirige...
# 12  En la cuarta casa de tormento en Xilbalba, me ...

# %%
#filename = cardLinkList[0].replace('https://myl.fandom.com/es/wiki/', '')
df.to_csv('Listado_Cartas_La_Ira_Del_Nahual' + '.csv', index=False)
#df = pd.DataFrame(columns=['N', 'Nombre', 'Tipo', 'Frecuencia', 'Arte'])

# Collecting Ddata
#for row in cardTable.tbody.find_all('tr'):    
    # Find all data for each column
 #   columns = row.find_all('td')
  #  if(columns != []):
   #     N = columns[0].text.strip()
    #    Nombre = columns[1].text.strip()
     #   Tipo = columns[2].text.strip()
      #  Frecuencia = columns[3].text.strip()
       # Arte = columns[4].text.strip()

        
        #output = df.concat({'N': N, 'Nombre': Nombre})

# %%
#df = pd.DataFrame(columns=['N', 'Nombre'])

# Collecting Ddata
#for row in cardTable.tbody.find_all('tr'):    
    # Find all data for each column
    #columns = row.find_all('td')
    #if(columns != []):
    #    N = columns[0].text.strip()
    #    Nombre = columns[1].text.strip()
        
    #    output = df.concat({'N': N, 'Nombre': Nombre})

# %%
#///// ACTUALIZAR CUANDO LOGRE OBTENER LINKS DE TABLAS

#for link in decksLinkFE:
#    cardList = f'{root}{link}'
#    #print (cardList)
#    df = pd.read_html(cardList)
#    #print (df)
#    filename = cardList.replace('https://myl.fandom.com/es/wiki/', '')
#    print(filename)
#    df[1].to_csv(filename + '.csv', index=False)

# %%
#cardList = f'{root}{decksLinkFE[0]}'

#sp = bs.BeautifulSoup(cardList, 'lxml')
#tb = sp.find_all('table')[56] 
#df = pd.read_html(str(tb),encoding='utf-8', header=0)[0]

#print (cardList)
#df = pd.read_html(cardList)
#df['href'] = [np.where(tag.has_attr('href'),tag.get('href'),"no link") for tag in tb.find_all('a')]

    #print (df)

# %%
cardList = f'{root}{cardLinks[2][1]}'
#print(cardList)
page_html = requests.get(cardList)
page_soup = soup(page_html.text, "lxml")
card_tables = page_soup.findAll('table', class_='table_black')


cardDetail =[]

#print(card_tables[3])

# Primera Tabla [0]... Header contiene nombre de Carta / Image contiene imagen / Description contiene: Tipo, Coste, Edición, Frecuencia
table_header = card_tables[0].find('tr', class_='table_head_black')
table_image = card_tables[0].find('tr', class_='table_body_black') 
#table_description = card_tables[0].findAll('tr', class_='') 

title = table_header.find('b').getText()
cardDetail.append(title)
cardImage = table_image.find('a', class_='image')

cardDetail.append(cardImage['href'])

#print(table_description)
#print(len(table_description))
#for row in table_description:
#a = table_description[0].find('th').text.strip('\n')
#b = table_description[1].find_next('th').text.strip('\n')
#c = table_description[2].find('th').text.strip('\n')
#d = table_description[3].find('th').text.strip('\n')
#e = table_description[4].find('th').text.strip('\n')


card_description = []
table_description = card_tables[0].findAll('tr', class_='') 
#print(table_description)
tr = card_tables[0].findAll('tr', class_='')

typeFlag = 0
costFlag = 0
frecFlag = 0
editionFlag = 0

typeCard = ''
costCard = ''
frecCard = ''
editionCard = ''

for row in tr:
    #print(row)
    th = row.find('th')
    if th.getText().strip() == "Tipo":
        print('Entre Tipo')
        typeCard = th.find_next('th').getText().strip('\n')
        typeFlag = 1
    elif th.getText().strip() == "Coste de oro":
        print('Entre Coste')
        costCard = th.find_next('th').getText().strip('\n')
        costFlag = 1
    elif th.getText().strip() == "Frecuencia":
        print('Entre Frecuencia')
        frecCard = th.find_next('th').getText().strip('\n')
        frecFlag = 1
    elif th.getText().strip() == "Edición":
        print('Entre Edicion')
        editionCard = th.find_next('th').getText().strip('\n')
        editionFlag = 1
    
if costFlag != 0:
 card_description.append(typeCard)
 card_description.append(costCard)
 card_description.append(frecCard)
 card_description.append(editionCard)
else:
 card_description.append(typeCard)
 card_description.append('Sin Costo')
 card_description.append(frecCard)
 card_description.append(editionCard)
 
print(card_description)

# table_description = card_tables[0].findAll('tr', class_='') 
#print(table_description)
#tr = card_tables[0].find('tr', class_='')
#print(tr)
#th = tr.find('th')
#if th.getText().strip() == "Tipo":
#        print(th.find_next('th').getText().strip('\n'))
#if th.getText().strip() == "Coste de Oro":
#        print(th.find_next('th').getText().strip('\n'))
                

# Impresión Segunda y tercera Tabla [1]...
#Para Cartas con Habilidad: Header contiene Label Habilidad / Body descripción de la habilidad.
#Para Cartas sin Habilidad: Contiene el Código y Arte  


#Valido si la carta tiene Habilidad#

card_with_hability = card_tables[1].find('td')

if (card_with_hability.getText().strip('\n') == "Habilidad"):
    #print('Si tengo')
    hability_flag = 1
    tr = card_tables[1].find('tr')
    td = tr.find('td')
    cardDetail.append(td.find_next('td').text.strip())
    
    more_details = card_tables[2].find('tr', class_='table_body_black')
    #print(more_details)
    for td in more_details.find('td'):
        cardDetail.append(td.text.strip())
        cardDetail.append(td.find_next('td').text.strip())
        
    card_history = card_tables[3].find('tr', class_='table_body_black')
    #print(more_details)
    for td in card_history.find('td'):
        #print(td.text.strip())
        cardDetail.append(td.text.strip())
        #cardDetail.append(td.find_next('td').text.strip())
        
#Carta sin Habilidad#            
else: 
    #print('No tengo')
    cardDetail.append('Sin Habilidad')
    more_details = card_tables[1].find('tr', class_='table_body_black')
    #print(more_details)
    for td in more_details.find('td'):
        cardDetail.append(td.text.strip())
        cardDetail.append(td.find_next('td').text.strip())
 
    card_history = card_tables[2].find('tr', class_='table_body_black')
    #print(more_details)
    for td in card_history.find('td'):
        #print(td.text.strip())
        cardDetail.append(td.text.strip())
        
        
#print(cardDetail)
# Out:
# Entre Tipo
# Entre Frecuencia
# Entre Edicion
# ['Oro', 'Sin Costo', 'Sin Frecuencia', 'El Reto']
